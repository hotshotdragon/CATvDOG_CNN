# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time

#NAME = 'Cats-vs-dog-cnn-64x2-{}'.format(int(time.time()))
tensorboard = TensorBoard(log_dir = 'logs/CATSvDOGS')

X = pickle.load(open('X.pickle','rb'))
y = pickle.load(open('y.pickle','rb'))

X=np.array(X/255.0)
y=np.array(y)

dense_layers = [0,1,2]
layer_sizes = [32,64,128]
conv_layers = [1,2,3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense{}".format(conv_layer,layer_size,dense_layer,int(time.time()))
            print(NAME)
            model = Sequential()
            model.add(Conv2D(layer_size, (3,3), input_shape = X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size = (2,2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3,3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size = (2,2)))

            model.add(Flatten()) #this converts 3D feature maps to 1D feature vectors
            for l in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))
            
            model.add(Dense(1))
            model.add(Activation('sigmoid'))

            model.compile(loss = 'binary_crossentropy',
                         optimizer='adam',
                         metrics = ['accuracy'])
            model.fit(X,y,batch_size = 32,epochs = 5, validation_split = 0.1,callbacks=[tensorboard])
# Out:
# 1-conv-32-nodes-0-dense1594399443
# Epoch 1/5
# 702/702 [==============================] - 29s 41ms/step - loss: 0.6185 - accuracy: 0.6604 - val_loss: 0.5961 - val_accuracy: 0.6790
# Epoch 2/5
# 702/702 [==============================] - 29s 41ms/step - loss: 0.5507 - accuracy: 0.7240 - val_loss: 0.5518 - val_accuracy: 0.7355
# Epoch 3/5
# 702/702 [==============================] - 29s 41ms/step - loss: 0.5165 - accuracy: 0.7499 - val_loss: 0.5473 - val_accuracy: 0.7355
# Epoch 4/5
# 702/702 [==============================] - 29s 42ms/step - loss: 0.4959 - accuracy: 0.7609 - val_loss: 0.5295 - val_accuracy: 0.7399
# Epoch 5/5
# 702/702 [==============================] - 29s 41ms/step - loss: 0.4835 - accuracy: 0.7695 - val_loss: 0.5344 - val_accuracy: 0.7431
# 2-conv-32-nodes-0-dense1594399588
# Epoch 1/5
# 702/702 [==============================] - 63s 89ms/step - loss: 0.6285 - accuracy: 0.6367 - val_loss: 0.6106 - val_accuracy: 0.6810
# Epoch 2/5
# 702/702 [==============================] - 62s 89ms/step - loss: 0.5338 - accuracy: 0.7337 - val_loss: 0.5255 - val_accuracy: 0.7443
# Epoch 3/5
# 702/702 [==============================] - 65s 92ms/step - loss: 0.4965 - accuracy: 0.7624 - val_loss: 0.5085 - val_accuracy: 0.7615
# Epoch 4/5
# 702/702 [==============================] - 64s 91ms/step - loss: 0.4742 - accuracy: 0.7748 - val_loss: 0.4961 - val_accuracy: 0.7699
# Epoch 5/5
# 702/702 [==============================] - 69s 98ms/step - loss: 0.4560 - accuracy: 0.7865 - val_loss: 0.5071 - val_accuracy: 0.7607
# 3-conv-32-nodes-0-dense1594399911
# Epoch 1/5
# 702/702 [==============================] - 77s 109ms/step - loss: 0.6363 - accuracy: 0.6317 - val_loss: 0.5857 - val_accuracy: 0.7074
# Epoch 2/5
# 702/702 [==============================] - 70s 99ms/step - loss: 0.5480 - accuracy: 0.7228 - val_loss: 0.5298 - val_accuracy: 0.7467
# Epoch 3/5
# 702/702 [==============================] - 78s 112ms/step - loss: 0.4998 - accuracy: 0.7587 - val_loss: 0.5275 - val_accuracy: 0.7427
# Epoch 4/5
# 702/702 [==============================] - 82s 116ms/step - loss: 0.4704 - accuracy: 0.7758 - val_loss: 0.4854 - val_accuracy: 0.7800
# Epoch 5/5
# 702/702 [==============================] - 85s 121ms/step - loss: 0.4432 - accuracy: 0.7934 - val_loss: 0.4782 - val_accuracy: 0.7880
# 1-conv-64-nodes-0-dense1594400305
# Epoch 1/5
# 702/702 [==============================] - 55s 79ms/step - loss: 0.6113 - accuracy: 0.6652 - val_loss: 0.5671 - val_accuracy: 0.7226
# Epoch 2/5
# 702/702 [==============================] - 53s 75ms/step - loss: 0.5399 - accuracy: 0.7305 - val_loss: 0.5561 - val_accuracy: 0.7319
# Epoch 3/5
# 702/702 [==============================] - 54s 76ms/step - loss: 0.5033 - accuracy: 0.7579 - val_loss: 0.5506 - val_accuracy: 0.7263
# Epoch 4/5
# 702/702 [==============================] - 57s 82ms/step - loss: 0.4794 - accuracy: 0.7733 - val_loss: 0.5433 - val_accuracy: 0.7339
# Epoch 5/5
# 702/702 [==============================] - 53s 76ms/step - loss: 0.4666 - accuracy: 0.7803 - val_loss: 0.5971 - val_accuracy: 0.6974
# 2-conv-64-nodes-0-dense1594400579
# Epoch 1/5
# 702/702 [==============================] - 149s 213ms/step - loss: 0.6033 - accuracy: 0.6687 - val_loss: 0.5359 - val_accuracy: 0.7363
# Epoch 2/5
# 702/702 [==============================] - 148s 211ms/step - loss: 0.5006 - accuracy: 0.7581 - val_loss: 0.5062 - val_accuracy: 0.7683
# Epoch 3/5
# 702/702 [==============================] - 143s 204ms/step - loss: 0.4661 - accuracy: 0.7793 - val_loss: 0.5117 - val_accuracy: 0.7523
# Epoch 4/5
# 702/702 [==============================] - 147s 210ms/step - loss: 0.4430 - accuracy: 0.7938 - val_loss: 0.4920 - val_accuracy: 0.7703
# Epoch 5/5
# 702/702 [==============================] - 146s 208ms/step - loss: 0.4176 - accuracy: 0.8099 - val_loss: 0.4596 - val_accuracy: 0.7896
# 3-conv-64-nodes-0-dense1594401314
# Epoch 1/5
# 702/702 [==============================] - 156s 222ms/step - loss: 0.6528 - accuracy: 0.6089 - val_loss: 0.5881 - val_accuracy: 0.6994
# Epoch 2/5
# 702/702 [==============================] - 157s 223ms/step - loss: 0.5410 - accuracy: 0.7293 - val_loss: 0.5088 - val_accuracy: 0.7579
# Epoch 3/5
# 702/702 [==============================] - 179s 255ms/step - loss: 0.4867 - accuracy: 0.7653 - val_loss: 0.5130 - val_accuracy: 0.7623
# Epoch 4/5
# 702/702 [==============================] - 166s 236ms/step - loss: 0.4503 - accuracy: 0.7876 - val_loss: 0.4856 - val_accuracy: 0.7695
# Epoch 5/5
# 702/702 [==============================] - 169s 240ms/step - loss: 0.4214 - accuracy: 0.8076 - val_loss: 0.4517 - val_accuracy: 0.7896
# 1-conv-128-nodes-0-dense1594402143
# Epoch 1/5
# 702/702 [==============================] - 94s 134ms/step - loss: 0.6209 - accuracy: 0.6516 - val_loss: 0.5881 - val_accuracy: 0.6958
# Epoch 2/5
# 702/702 [==============================] - 93s 132ms/step - loss: 0.5411 - accuracy: 0.7298 - val_loss: 0.5454 - val_accuracy: 0.7403
# Epoch 3/5
# 702/702 [==============================] - 92s 130ms/step - loss: 0.5061 - accuracy: 0.7548 - val_loss: 0.5367 - val_accuracy: 0.7387
# Epoch 4/5
# 702/702 [==============================] - 92s 131ms/step - loss: 0.4778 - accuracy: 0.7735 - val_loss: 0.5398 - val_accuracy: 0.7403
# Epoch 5/5
# 702/702 [==============================] - 92s 131ms/step - loss: 0.4545 - accuracy: 0.7867 - val_loss: 0.5381 - val_accuracy: 0.7371
# 2-conv-128-nodes-0-dense1594402607
# Epoch 1/5
# 702/702 [==============================] - 399s 569ms/step - loss: 0.6062 - accuracy: 0.6605 - val_loss: 0.5257 - val_accuracy: 0.7491
# Epoch 2/5
# 702/702 [==============================] - 395s 563ms/step - loss: 0.5078 - accuracy: 0.7581 - val_loss: 0.5027 - val_accuracy: 0.7659
# Epoch 3/5
# 702/702 [==============================] - 392s 559ms/step - loss: 0.4627 - accuracy: 0.7827 - val_loss: 0.4753 - val_accuracy: 0.7904
# Epoch 4/5
# 702/702 [==============================] - 394s 562ms/step - loss: 0.4362 - accuracy: 0.7963 - val_loss: 0.4643 - val_accuracy: 0.7956
# Epoch 5/5
# 702/702 [==============================] - 397s 565ms/step - loss: 0.4001 - accuracy: 0.8201 - val_loss: 0.4600 - val_accuracy: 0.7916
# 3-conv-128-nodes-0-dense1594404588
# Epoch 1/5
# 702/702 [==============================] - 434s 619ms/step - loss: 0.6220 - accuracy: 0.6453 - val_loss: 0.5310 - val_accuracy: 0.7403
# Epoch 2/5
# 702/702 [==============================] - 435s 619ms/step - loss: 0.5070 - accuracy: 0.7497 - val_loss: 0.4789 - val_accuracy: 0.7816
# Epoch 3/5
# 702/702 [==============================] - 434s 619ms/step - loss: 0.4409 - accuracy: 0.7979 - val_loss: 0.4715 - val_accuracy: 0.7840
# Epoch 4/5
# 702/702 [==============================] - 434s 618ms/step - loss: 0.3942 - accuracy: 0.8225 - val_loss: 0.4314 - val_accuracy: 0.8068
# Epoch 5/5
# 702/702 [==============================] - 434s 619ms/step - loss: 0.3544 - accuracy: 0.8425 - val_loss: 0.4116 - val_accuracy: 0.8204
# 1-conv-32-nodes-1-dense1594406764
# Epoch 1/5
# 524/702 [=====================>........] - ETA: 9s - loss: 0.6294 - accuracy: 0.6459
